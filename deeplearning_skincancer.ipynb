# %% [markdown]
# <a href="https://colab.research.google.com/github/tusharbelwal7/Skin_cancer_prediction_deeplearning/blob/main/deeplearning_skincancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import tensorflow as tf, numpy as np, pandas as pd
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Input
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
train_path = '/content/drive/MyDrive/deep learning/melanoma_cancer_dataset/train'
ds = keras.utils.image_dataset_from_directory(
    directory = train_path,
    labels= 'inferred',
    label_mode= 'int',
    batch_size= 32,
    image_size = (256, 256),
    shuffle =True,
)
# Out:
# Found 9622 files belonging to 2 classes.

# %%
test_path = '/content/drive/MyDrive/deep learning/melanoma_cancer_dataset/test'
test= keras.utils.image_dataset_from_directory(
    directory = test_path,
    labels= 'inferred',
    label_mode= 'int',
    batch_size= 32,
    image_size= (256, 256),
    shuffle = True,
)
# Out:
# Found 1000 files belonging to 2 classes.

# %% [markdown]
# DATASET SPLITTING

# %%
DATASET_SIZE= len(ds)
TRAIN_RATIO, VALIDATION_RATIO = 0.8, 0.2
train = ds.take(int(DATASET_SIZE*TRAIN_RATIO))
val  = ds.skip(int(DATASET_SIZE*TRAIN_RATIO))

print(len(train), len(val))
# Out:
# 240 61

# %% [markdown]
# DATASET VISUALIZATION

# %%
import matplotlib.pyplot as plt

# %%
class_names = ds.class_names
plt.figure(figsize= (10,10))
for image_batch, label_batch in ds.take(1):
    for i in range(12):
        ax = plt.subplot(4,3,i+1)
        plt.imshow(image_batch[i].numpy().astype('uint8'))
        plt.title(class_names[label_batch[i]]); plt.axis('off')

# %%
from keras.layers import RandomFlip, RandomRotation

# %%
Augmentation = Sequential([
    RandomFlip("horizontal_and_vertical"),
    RandomRotation(0.2),
])

# %%
def Normalizer(image, label):
    image= tf.cast(image/255., tf.float32)
    return image, label
train, val, test = train.map(Normalizer), val.map(Normalizer), test.map(Normalizer)

# %%
model = Sequential([
    Augmentation,
    Conv2D(32, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Conv2D(32, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Conv2D(32, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Conv2D(32, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Conv2D(32, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Conv2D(32, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Flatten(),
    Dense(units=64, activation="relu"),
    Dense(units=2, activation="softmax"),
])

model.build (input_shape=(None, 256, 256, 3))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 256, 256, 3)       0
#
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 127, 127, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      9248
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 62, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 32)        9248
#
#  max_pooling2d_2 (MaxPoolin  (None, 30, 30, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 32)        9248
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 32)        9248
#
#  max_pooling2d_4 (MaxPoolin  (None, 6, 6, 32)          0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 32)          9248
#
#  max_pooling2d_5 (MaxPoolin  (None, 2, 2, 32)          0
#  g2D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 55522 (216.88 KB)
# Trainable params: 55522 (216.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    optimizer= 'adam',
    loss=  'sparse_categorical_crossentropy',
    metrics = ['accuracy',]
)

# %%
from keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(
    monitor = 'accuracy',
    patience = 3,
    restore_best_weights = True,
)

# %% [markdown]
# MODEL TRAINING

# %%
history = model.fit(train, batch_size= 32, epochs=25, verbose=1, validation_data=val, callbacks=[early_stopping])
# Out:
# Epoch 1/25
# 240/240 [==============================] - 1015s 4s/step - loss: 0.4980 - accuracy: 0.7414 - val_loss: 0.3747 - val_accuracy: 0.8476
# Epoch 2/25
# 240/240 [==============================] - 935s 4s/step - loss: 0.3495 - accuracy: 0.8518 - val_loss: 0.3419 - val_accuracy: 0.8517
# Epoch 3/25
# 240/240 [==============================] - 885s 4s/step - loss: 0.3254 - accuracy: 0.8617 - val_loss: 0.3302 - val_accuracy: 0.8548
# Epoch 4/25
# 240/240 [==============================] - 926s 4s/step - loss: 0.3309 - accuracy: 0.8616 - val_loss: 0.3103 - val_accuracy: 0.8774
# Epoch 5/25
# 240/240 [==============================] - 900s 4s/step - loss: 0.3099 - accuracy: 0.8716 - val_loss: 0.2935 - val_accuracy: 0.8841
# Epoch 6/25
# 240/240 [==============================] - 919s 4s/step - loss: 0.3031 - accuracy: 0.8710 - val_loss: 0.2809 - val_accuracy: 0.8836
# Epoch 7/25
# 240/240 [==============================] - 922s 4s/step - loss: 0.2953 - accuracy: 0.8768 - val_loss: 0.2783 - val_accuracy: 0.8877
# Epoch 8/25
# 240/240 [==============================] - 939s 4s/step - loss: 0.2903 - accuracy: 0.8783 - val_loss: 0.3495 - val_accuracy: 0.8512
# Epoch 9/25
# 240/240 [==============================] - 862s 4s/step - loss: 0.2853 - accuracy: 0.8831 - val_loss: 0.3639 - val_accuracy: 0.8574
# Epoch 10/25
# 240/240 [==============================] - 912s 4s/step - loss: 0.2898 - accuracy: 0.8762 - val_loss: 0.2756 - val_accuracy: 0.8867
# Epoch 11/25
# 240/240 [==============================] - 819s 3s/step - loss: 0.2758 - accuracy: 0.8831 - val_loss: 0.2573 - val_accuracy: 0.8872
# Epoch 12/25
# 240/240 [==============================] - 899s 4s/step - loss: 0.2768 - accuracy: 0.8836 - val_loss: 0.3327 - val_accuracy: 0.8661
# Epoch 13/25
# 240/240 [==============================] - 905s 4s/step - loss: 0.2691 - accuracy: 0.8852 - val_loss: 0.2616 - val_accuracy: 0.8867
# Epoch 14/25
# 240/240 [==============================] - 932s 4s/step - loss: 0.2616 - accuracy: 0.8884 - val_loss: 0.2519 - val_accuracy: 0.8867
# Epoch 15/25
# 240/240 [==============================] - 909s 4s/step - loss: 0.2638 - accuracy: 0.8891 - val_loss: 0.2799 - val_accuracy: 0.8872
# Epoch 16/25
# 240/240 [==============================] - 865s 4s/step - loss: 0.2713 - accuracy: 0.8870 - val_loss: 0.2581 - val_accuracy: 0.8970
# Epoch 17/25
# 240/240 [==============================] - 904s 4s/step - loss: 0.2572 - accuracy: 0.8915 - val_loss: 0.2489 - val_accuracy: 0.8965
# Epoch 18/25
# 240/240 [==============================] - 911s 4s/step - loss: 0.2583 - accuracy: 0.8889 - val_loss: 0.2678 - val_accuracy: 0.8862
# Epoch 19/25
# 240/240 [==============================] - 913s 4s/step - loss: 0.2537 - accuracy: 0.8918 - val_loss: 0.2446 - val_accuracy: 0.8929
# Epoch 20/25
# 240/240 [==============================] - 956s 4s/step - loss: 0.2519 - accuracy: 0.8928 - val_loss: 0.2496 - val_accuracy: 0.9042
# Epoch 21/25
# 240/240 [==============================] - 895s 4s/step - loss: 0.2540 - accuracy: 0.8934 - val_loss: 0.2429 - val_accuracy: 0.8934
# Epoch 22/25
# 240/240 [==============================] - 903s 4s/step - loss: 0.2390 - accuracy: 0.8980 - val_loss: 0.2327 - val_accuracy: 0.9037
# Epoch 23/25
# 240/240 [==============================] - 901s 4s/step - loss: 0.2452 - accuracy: 0.8952 - val_loss: 0.2449 - val_accuracy: 0.9027
# Epoch 24/25
# 240/240 [==============================] - 862s 4s/step - loss: 0.2477 - accuracy: 0.8987 - val_loss: 0.2345 - val_accuracy: 0.9011
# Epoch 25/25
# 240/240 [==============================] - 889s 4s/step - loss: 0.2448 - accuracy: 0.8962 - val_loss: 0.2521 - val_accuracy: 0.8980

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['train', 'validation'])

# %% [markdown]
# MODEL EVALUATION

# %%
loss, accuracy = model.evaluate(test); print(loss, accuracy)
# Out:
# 32/32 [==============================] - 144s 3s/step - loss: 0.2581 - accuracy: 0.8920
# 0.2581457495689392 0.8920000195503235

# %%
for images, label in test.take(1):
  img = (images[0]*255).numpy().astype('uint8')
  plt.imshow(img)
  print('Actual Label: ', class_names[label[0].numpy()])
  pred = model.predict(images)
  print('Predicted Label: ', class_names[np.argmax(pred[0])])

# %% [markdown]
# CONFUSION MATRIX & PERFORMANCE EVALUATION

# %%
true, predicted = [], []
for images, labels in test:
    for img, label in zip(images, labels):
        true.append(label.numpy())
        pred = model.predict(tf.expand_dims(img, axis=0))
        predicted.append(np.argmax(pred[0]))

# %%
cm = confusion_matrix(true, predicted)
cm_matrix = pd.DataFrame(data=cm, columns=['Predicted Positive:1', 'Predicted Negative:0'], index=['Actual Positive:1', 'Actual Negative:0'])

sns.heatmap(cm_matrix, annot=True, fmt = 'd', cmap='mako')
# Out:
# <Axes: >
